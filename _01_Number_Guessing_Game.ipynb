# %% [markdown]
# <a href="https://colab.research.google.com/github/ozadacagatay/Pyhton_projects/blob/main/_01_Number_Guessing_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
attempts = 7

def display_rules():
  print("Welcome to Number Guessing Game!\n")
  print("I have selected a number between 1 and 100.")
  print("You have 7 attempts to guess the number.")
  print("Let's begin!\n")

def play_game(number, attempt=1):
    if attempt > attempts:
      print("\nGame Over!")
      print("The correct number was:", number)
      return

    guess = input(f"Attempt {attempt}/7 - Enter your guess: ")
    try:
      guess = int(guess)
    except ValueError:
      print("Please enter a valid number.\n")
      return play_game(number, attempt)
    if guess < 1 or guess > 100:
      print("Please enter a number between 1 and 100.\n")
      return play_game(number, attempt)
    check_guess = lambda x, y: "correct" if x== y else (
        "low" if x < y else "high"
    )
    result = check_guess(guess, number)
    if result == "correct":
      print("\nCongratulations! You guessed the correct number!")
      print("You guessed it in", attempt, "attempt(s).")
      return
    if result == "low":
      print("Too low! Try a higher number.\n")
    else:
      print("Too High! Try a lower number.\n")
    play_game(number, attempt + 1)

display_rules()
random_number = random.randint(1, 100)
play_game(random_number)
# Out:
# Welcome to Number Guessing Game!
#
# I have selected a number between 1 and 100.
# You have 7 attempts to guess the number.
# Let's begin!
#
# Attempt 1/7 - Enter your guess: 56
# Too High! Try a lower number.
#
# Attempt 2/7 - Enter your guess: 25
# Too low! Try a higher number.
#
# Attempt 3/7 - Enter your guess: 36
# Too low! Try a higher number.
#
# Attempt 4/7 - Enter your guess: 43
# Too High! Try a lower number.
#
# Attempt 5/7 - Enter your guess: 40
# Too low! Try a higher number.
#
# Attempt 6/7 - Enter your guess: 41
#
# Congratulations! You guessed the correct number!
# You guessed it in 6 attempt(s).

# %% [markdown]
# Bu kod, 1 ile 100 arasında rastgele bir sayı belirleyen ve kullanıcının bu sayıyı 7 deneme içinde tahmin etmeye çalıştığı basit bir numara tahmin oyunu oluşturur. İşte kodun her bir bölümünün açıklaması:
#
# ### 1. Kitaplık İçe Aktarma ve Değişken Tanımlama
#
# ```python
# import random
# attempts = 7
# ```
# *   `import random`: Python'ın `random` modülünü içe aktarır. Bu modül, oyun için rastgele bir sayı oluşturmak üzere kullanılır.
# *   `attempts = 7`: Oyuncunun sahip olacağı toplam tahmin deneme sayısını belirten bir değişkendir. Bu durumda, oyuncunun 7 hakkı vardır.
#
# ### 2. Kuralları Görüntüleme Fonksiyonu (`display_rules`)
#
# ```python
# def display_rules():
#   print("Welcome to Number Guessing Game!\n")
#   print("I have selected a number between 1 and 100.")
#   print("You have 7 attempts to guess the number.")
#   print("Let's begin!\n")
# ```
# *   Bu fonksiyon, oyunun başlangıcında kullanıcılara oyunun kurallarını ve nasıl oynandığını açıklayan mesajları yazdırır.
#
# ### 3. Oyunu Oynama Fonksiyonu (`play_game`)
#
# ```python
# def play_game(number, attempt=1):
#     if attempt > attempts:
#       print("\nGame Over!")
#       print("The correct number was:", number)
#       return
# ```
# *   `play_game(number, attempt=1)`: Bu, oyunun ana mantığını içeren özyinelemeli bir fonksiyondur. `number` tahmin edilmesi gereken sayıdır ve `attempt` mevcut deneme sayısını takip eder, varsayılan olarak 1'den başlar.
# *   `if attempt > attempts:`: Eğer mevcut deneme sayısı (`attempt`), izin verilen maksimum deneme sayısını (`attempts`) aşarsa, oyun biter. Kullanıcıya "Game Over!" mesajı gösterilir ve doğru sayı açıklanır.
#
# ```python
#     guess = input(f"Attempt {attempt}/7 - Enter your guess: ")
#     try:
#       guess = int(guess)
#     except ValueError:
#       print("Please enter a valid number.\n")
#       return play_game(number, attempt)
# ```
# *   `guess = input(...)`: Kullanıcıdan bir tahmin girmesi istenir ve bu tahmin `guess` değişkenine atanır.
# *   `try-except ValueError`: Kullanıcının girdiği girdinin bir sayı olup olmadığını kontrol eder. Eğer sayı değilse (`ValueError`), bir hata mesajı gösterir ve aynı denemeyi tekrar başlatmak için fonksiyonu tekrar çağırır.
#
# ```python
#     if guess < 1 or guess > 100:
#       print("Please enter a number between 1 and 100.\n")
#       return play_game(number, attempt)
# ```
# *   `if guess < 1 or guess > 100:`: Kullanıcının tahmininin 1 ile 100 arasında olup olmadığını kontrol eder. Geçersiz bir aralıkta ise bir hata mesajı gösterir ve aynı denemeyi tekrar başlatmak için fonksiyonu tekrar çağırır.
#
# ```python
#     check_guess = lambda x, y: "correct" if x== y else (
#         "low" if x < y else "high"
#     )
#     result = check_guess(guess, number)
# ```
# *   `check_guess = lambda ...`: Tahmini (`x`) doğru sayı (`y`) ile karşılaştıran küçük, anonim bir fonksiyondur (lambda fonksiyonu). Sonucu "correct" (doğru), "low" (düşük) veya "high" (yüksek) olarak döndürür.
# *   `result = check_guess(guess, number)`: Kullanıcının tahminini rastgele seçilen sayıyla karşılaştırmak için `check_guess` lambda fonksiyonunu kullanır.
#
# ```python
#     if result == "correct":
#       print("\nCongratulations! You guessed the correct number!")
#       print("You guessed it in", attempt, "attempt(s).")
#       return
#     if result == "low":
#       print("Too low! Try a higher number.\n")
#     else:
#       print("Too High! Try a lower number.\n")
#     play_game(number, attempt + 1)
# ```
# *   `if result == "correct"`: Eğer tahmin doğruysa, tebrik mesajı yazdırılır ve fonksiyon sonlanır.
# *   `if result == "low"`: Eğer tahmin düşükse, kullanıcıya daha yüksek bir sayı denemesi gerektiği söylenir.
# *   `else`: Eğer tahmin yüksekse, kullanıcıya daha düşük bir sayı denemesi gerektiği söylenir.
# *   `play_game(number, attempt + 1)`: Tahmin doğru değilse, `attempt` sayısını bir artırarak fonksiyonu tekrar çağırır, böylece oyun bir sonraki denemeyle devam eder.
#
# ### 4. Oyunu Başlatma
#
# ```python
# display_rules()
# random_number = random.randint(1, 100)
# play_game(random_number)
# ```
# *   `display_rules()`: Oyunun kurallarını gösteren fonksiyonu çağırır.
# *   `random_number = random.randint(1, 100)`: 1 ile 100 (dahil) arasında rastgele bir tam sayı oluşturur ve bu sayıyı `random_number` değişkenine atar. Bu, kullanıcının tahmin etmesi gereken sayıdır.
# *   `play_game(random_number)`: Oyunu başlatmak için `play_game` fonksiyonunu çağırır ve oluşturulan rastgele sayıyı fonksiyona geçirir.
